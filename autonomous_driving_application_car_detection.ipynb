# %% [markdown]
# <a href="https://colab.research.google.com/github/thimeshaA/DeepLearningLab04/blob/main/autonomous_driving_application_car_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 4 – Autonomous Driving: Car Detection with CNNs**
#
# In this lab, you will explore **object detection** using the powerful **YOLO (You Only Look Once)** model, a state-of-the-art Convolutional Neural Network (CNN) for real-time detection tasks.
#
# By working through this exercise, you will:
# - Understand how to **represent and work with bounding boxes** in images.
# - Apply YOLO to detect **cars and other road objects** in realistic driving scenarios.
# - Experiment with **confidence thresholds, class filtering, and detection statistics** to see how model parameters affect results.
# - Visualize **CNN feature maps (activation heatmaps)** to gain intuition about how detectors “see” objects.
# - Analyze results to discuss **false positives, false negatives, and model sensitivity**.
#
# This lab builds directly on your **CNN lecture**, connecting core theory (convolutions, pooling, feature extraction) to a **real-world computer vision application**: **autonomous driving and traffic scene analysis**.

# %% [markdown]
# ## Mount the Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Extract the Zip Folder
#
# Change the path according to your file location

# %%
# !unzip "/content/drive/MyDrive/DL/Lab4.zip" -d "content/"
# Out:
# Archive:  /content/drive/MyDrive/DL/Lab4.zip
# replace content/__MACOSX/._Lab4? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/._Lab4
# replace content/__MACOSX/Lab4/._model_data? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/._model_data
# replace content/__MACOSX/Lab4/._images? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/._images
# replace content/__MACOSX/Lab4/._yad2k? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/._yad2k
# replace content/__MACOSX/Lab4/.___pycache__? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/.___pycache__
# replace content/Lab4/yolo_utils.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yolo_utils.py
# replace content/__MACOSX/Lab4/._yolo_utils.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/._yolo_utils.py
# replace content/__MACOSX/Lab4/._.ipynb_checkpoints? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/._.ipynb_checkpoints
# replace content/__MACOSX/Lab4/._font? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/._font
# replace content/Lab4/model_data/yolo_anchors.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/model_data/yolo_anchors.txt
# replace content/__MACOSX/Lab4/model_data/._yolo_anchors.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/model_data/._yolo_anchors.txt
# replace content/Lab4/model_data/coco_classes.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/model_data/coco_classes.txt
# replace content/__MACOSX/Lab4/model_data/._coco_classes.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/model_data/._coco_classes.txt
# replace content/Lab4/images/0105.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0105.jpg
# replace content/__MACOSX/Lab4/images/._0105.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0105.jpg
# replace content/Lab4/images/0111.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0111.jpg
# replace content/__MACOSX/Lab4/images/._0111.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0111.jpg
# replace content/Lab4/images/0110.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0110.jpg
# replace content/__MACOSX/Lab4/images/._0110.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0110.jpg
# replace content/Lab4/images/0104.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0104.jpg
# replace content/__MACOSX/Lab4/images/._0104.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0104.jpg
# replace content/Lab4/images/0112.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0112.jpg
# replace content/__MACOSX/Lab4/images/._0112.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0112.jpg
# replace content/Lab4/images/0106.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0106.jpg
# replace content/__MACOSX/Lab4/images/._0106.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0106.jpg
# replace content/Lab4/images/0107.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0107.jpg
# replace content/__MACOSX/Lab4/images/._0107.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0107.jpg
# replace content/Lab4/images/0113.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0113.jpg
# replace content/__MACOSX/Lab4/images/._0113.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0113.jpg
# replace content/Lab4/images/0117.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0117.jpg
# replace content/__MACOSX/Lab4/images/._0117.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0117.jpg
# replace content/Lab4/images/0103.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0103.jpg
# replace content/__MACOSX/Lab4/images/._0103.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0103.jpg
# replace content/Lab4/images/0102.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0102.jpg
# replace content/__MACOSX/Lab4/images/._0102.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0102.jpg
# replace content/Lab4/images/0116.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0116.jpg
# replace content/__MACOSX/Lab4/images/._0116.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0116.jpg
# replace content/Lab4/images/0100.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0100.jpg
# replace content/__MACOSX/Lab4/images/._0100.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0100.jpg
# replace content/Lab4/images/0114.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0114.jpg
# replace content/__MACOSX/Lab4/images/._0114.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0114.jpg
# replace content/Lab4/images/0115.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0115.jpg
# replace content/__MACOSX/Lab4/images/._0115.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0115.jpg
# replace content/Lab4/images/0101.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0101.jpg
# replace content/__MACOSX/Lab4/images/._0101.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0101.jpg
# replace content/Lab4/images/test.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/test.jpg
# replace content/__MACOSX/Lab4/images/._test.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._test.jpg
# replace content/Lab4/images/0118.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0118.jpg
# replace content/__MACOSX/Lab4/images/._0118.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0118.jpg
# replace content/Lab4/images/0119.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0119.jpg
# replace content/__MACOSX/Lab4/images/._0119.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0119.jpg
# replace content/Lab4/images/DSC_1643_resized.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/DSC_1643_resized.jpg
# replace content/__MACOSX/Lab4/images/._DSC_1643_resized.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._DSC_1643_resized.jpg
# replace content/Lab4/images/0109.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0109.jpg
# replace content/__MACOSX/Lab4/images/._0109.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0109.jpg
# replace content/Lab4/images/giraffe_resized.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/giraffe_resized.jpg
# replace content/__MACOSX/Lab4/images/._giraffe_resized.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._giraffe_resized.jpg
# replace content/Lab4/images/0120.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0120.jpg
# replace content/__MACOSX/Lab4/images/._0120.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0120.jpg
# replace content/Lab4/images/0108.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/images/0108.jpg
# replace content/__MACOSX/Lab4/images/._0108.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/images/._0108.jpg
# replace content/__MACOSX/Lab4/yad2k/._utils? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/._utils
# replace content/__MACOSX/Lab4/yad2k/._models? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/._models
# replace content/Lab4/__pycache__/yolo_utils.cpython-312.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/__pycache__/yolo_utils.cpython-312.pyc
# replace content/__MACOSX/Lab4/__pycache__/._yolo_utils.cpython-312.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/__pycache__/._yolo_utils.cpython-312.pyc
# replace content/Lab4/font/SIL+Open+Font+License.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/font/SIL+Open+Font+License.txt
# replace content/__MACOSX/Lab4/font/._SIL+Open+Font+License.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/font/._SIL+Open+Font+License.txt
# replace content/Lab4/font/FiraMono-Medium.otf? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/font/FiraMono-Medium.otf
# replace content/__MACOSX/Lab4/font/._FiraMono-Medium.otf? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/font/._FiraMono-Medium.otf
# replace content/Lab4/yad2k/utils/__init__.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/utils/__init__.py
# replace content/__MACOSX/Lab4/yad2k/utils/.___init__.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/utils/.___init__.py
# replace content/__MACOSX/Lab4/yad2k/utils/.___pycache__? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/utils/.___pycache__
# replace content/Lab4/yad2k/utils/utils.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/utils/utils.py
# replace content/__MACOSX/Lab4/yad2k/utils/._utils.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/utils/._utils.py
# replace content/Lab4/yad2k/models/keras_darknet19.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/models/keras_darknet19.py
# replace content/__MACOSX/Lab4/yad2k/models/._keras_darknet19.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/models/._keras_darknet19.py
# replace content/__MACOSX/Lab4/yad2k/models/.___pycache__? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/models/.___pycache__
# replace content/Lab4/yad2k/models/keras_yolo.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/models/keras_yolo.py
# replace content/__MACOSX/Lab4/yad2k/models/._keras_yolo.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/models/._keras_yolo.py
# replace content/Lab4/yad2k/utils/__pycache__/__init__.cpython-39.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/utils/__pycache__/__init__.cpython-39.pyc
# replace content/__MACOSX/Lab4/yad2k/utils/__pycache__/.___init__.cpython-39.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/utils/__pycache__/.___init__.cpython-39.pyc
# replace content/Lab4/yad2k/utils/__pycache__/utils.cpython-39.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/utils/__pycache__/utils.cpython-39.pyc
# replace content/__MACOSX/Lab4/yad2k/utils/__pycache__/._utils.cpython-39.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/utils/__pycache__/._utils.cpython-39.pyc
# replace content/Lab4/yad2k/utils/__pycache__/utils.cpython-312.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/utils/__pycache__/utils.cpython-312.pyc
# replace content/__MACOSX/Lab4/yad2k/utils/__pycache__/._utils.cpython-312.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/utils/__pycache__/._utils.cpython-312.pyc
# replace content/Lab4/yad2k/utils/__pycache__/utils.cpython-310.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/utils/__pycache__/utils.cpython-310.pyc
# replace content/__MACOSX/Lab4/yad2k/utils/__pycache__/._utils.cpython-310.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/utils/__pycache__/._utils.cpython-310.pyc
# replace content/Lab4/yad2k/utils/__pycache__/__init__.cpython-312.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/utils/__pycache__/__init__.cpython-312.pyc
# replace content/__MACOSX/Lab4/yad2k/utils/__pycache__/.___init__.cpython-312.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/utils/__pycache__/.___init__.cpython-312.pyc
# replace content/Lab4/yad2k/utils/__pycache__/__init__.cpython-310.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/utils/__pycache__/__init__.cpython-310.pyc
# replace content/__MACOSX/Lab4/yad2k/utils/__pycache__/.___init__.cpython-310.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/utils/__pycache__/.___init__.cpython-310.pyc
# replace content/Lab4/yad2k/models/__pycache__/keras_darknet19.cpython-39.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/models/__pycache__/keras_darknet19.cpython-39.pyc
# replace content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_darknet19.cpython-39.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_darknet19.cpython-39.pyc
# replace content/Lab4/yad2k/models/__pycache__/keras_yolo.cpython-310.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/models/__pycache__/keras_yolo.cpython-310.pyc
# replace content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_yolo.cpython-310.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_yolo.cpython-310.pyc
# replace content/Lab4/yad2k/models/__pycache__/keras_yolo.cpython-39.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/models/__pycache__/keras_yolo.cpython-39.pyc
# replace content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_yolo.cpython-39.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_yolo.cpython-39.pyc
# replace content/Lab4/yad2k/models/__pycache__/keras_yolo.cpython-312.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/models/__pycache__/keras_yolo.cpython-312.pyc
# replace content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_yolo.cpython-312.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: yy
#   inflating: content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_yolo.cpython-312.pyc
# replace content/Lab4/yad2k/models/__pycache__/keras_darknet19.cpython-312.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/Lab4/yad2k/models/__pycache__/keras_darknet19.cpython-312.pyc
# replace content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_darknet19.cpython-312.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_darknet19.cpython-312.pyc
# replace content/Lab4/yad2k/models/__pycache__/keras_darknet19.cpython-310.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: yy
#   inflating: content/Lab4/yad2k/models/__pycache__/keras_darknet19.cpython-310.pyc
# replace content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_darknet19.cpython-310.pyc? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: content/__MACOSX/Lab4/yad2k/models/__pycache__/._keras_darknet19.cpython-310.pyc

# %% [markdown]
# # Import Packages and Setup

# %% [markdown]
# ### Setup and Dependencies
#
# In this step, we install and import the key libraries required for the lab:
#
# - **Ultralytics** - Provides the YOLOv8 object detection framework.
# - **OpenCV (cv2)** - Useful for image processing and computer vision utilities.
# - **Pillow (PIL)** - For handling and drawing on images.
# - **Matplotlib** - For plotting and visualizations.
# - **TensorFlow** - For exploring CNN concepts and verifying environment setup.
#
# We also check the TensorFlow version and whether **Eager Execution** is enabled, ensuring compatibility with modern deep learning workflows.

# %%
# !pip -q install --upgrade ultralytics opencv-python pillow matplotlib

import os, glob
import numpy as np
from typing import Tuple
from PIL import Image, ImageDraw
import tensorflow as tf
import matplotlib.pyplot as plt

print("TensorFlow:", tf.__version__)
print("Eager execution:", tf.executing_eagerly())
# Out:
# TensorFlow: 2.19.0
# Eager execution: True

# %%
import sys

sys.path.insert(0, "content/Lab4/")
import yolo_utils

# %% [markdown]
# ### Loading and Running YOLOv8
#
# In this section, we load a lightweight **pretrained YOLOv8 model** (`yolov8n.pt`) provided by Ultralytics.
# This model is trained on the COCO dataset and is suitable for fast inference on common objects, including cars.
#
# The helper function `run_yolov8` is defined to:
# - Run YOLO inference on a given image.
# - Apply a **confidence threshold** (default 0.25) to filter low-confidence detections.
# - Apply an **IoU threshold** (default 0.45) to control Non-Maximum Suppression (removing overlapping boxes).
# - Return three arrays:
#   - Bounding boxes in `(y1, x1, y2, x2)` format.
#   - Confidence scores for each detection.
#   - Predicted class IDs.
#
# This function standardizes outputs, making them easy to use for further analysis and visualization later in the lab.

# %%
from ultralytics import YOLO

# Load a small pretrained pytorch model
model = YOLO("yolov8n.pt")
print("Loaded YOLOv8 model")

def run_yolov8(image_path, score_threshold=0.25, iou_threshold=0.45):
  #score_threshold is the confidence level. more value more accurate
  #iou_threshold means the overlap. when higher more overlap
    results = model.predict(image_path, conf=score_threshold, iou=iou_threshold, verbose=False)
    if not results or results[0].boxes is None:
        return np.zeros((0,4), np.float32), np.zeros((0,), np.float32), np.zeros((0,), np.int32)
    r = results[0]
    xyxy = r.boxes.xyxy.cpu().numpy().astype(np.float32)  # (x1,y1,x2,y2)
    conf = r.boxes.conf.cpu().numpy().astype(np.float32)
    cls  = r.boxes.cls.cpu().numpy().astype(np.int32)
    yx = xyxy[:, [1,0,3,2]]  # → (y1,x1,y2,x2)
    return yx, conf, cls
# Out:
# Loaded YOLOv8 model

# %% [markdown]
# ### Drawing Detection Boxes on Images
#
# The function `draw_boxes` is used to visualize YOLO detections directly on images.
# It takes as input the image path, bounding boxes, confidence scores, and class labels, and then overlays them on the image.
#
# Key features of this function:
# - **Bounding box drawing**: Green rectangles are drawn around detected objects.
# - **Labels**: Each box is annotated with the class name (or ID) and its confidence score.
# - **Filtering options**:
#   - `min_score` filters out low-confidence predictions.
#   - `wanted_idx` allows drawing only a specific class (e.g., cars only).
# - **Font handling**: Attempts to use a TrueType font if available, otherwise defaults to system font.
# - **Saving results**: If `save_back=True`, the function saves the annotated image back to disk with a suffix (e.g., `_detected`).
#
# The function returns:
# 1. The annotated `PIL.Image` object.
# 2. The number of drawn detections.
# 3. The file path of the saved image (if saving is enabled).
#
# This step provides a convenient way to **inspect detection quality visually** and generate results for reports.

# %%
from PIL import ImageDraw, ImageFont

from PIL import ImageDraw, ImageFont

def draw_boxes(image_path, boxes, scores, classes,
               class_names=None, wanted_idx=None,
               min_score=0.25, font_path="font/arial.ttf",
               save_back=False, suffix="_detected"):
    """
    Draw boxes on image, optionally overwrite/save back into images folder.
    """
    img = Image.open(image_path).convert("RGB")
    draw = ImageDraw.Draw(img)
    try:
        font = ImageFont.truetype(font_path, 14)
    except:
        font = None

    count = 0
    for b, s, c in zip(boxes, scores, classes):
        if s < min_score:
            continue
        if wanted_idx is not None and c != wanted_idx:
            continue
        y1, x1, y2, x2 = [int(v) for v in b]
        draw.rectangle([x1, y1, x2, y2], outline=(0,255,0), width=3)
        label = f"{class_names[c] if class_names else c}: {s:.2f}"
        draw.text((x1+3, max(0, y1-12)), label, fill=(255,255,0), font=font)
        count += 1

    # save back into same folder
    if save_back:
        base, ext = os.path.splitext(image_path)
        new_path = f"{base}{suffix}{ext}"   # e.g. 0114_detected.jpg
        img.save(new_path)
        print(f"Saved annotated image: {new_path}")
        return img, count, new_path

    return img, count

# %% [markdown]
# ### Post-Processing with TensorFlow
#
# The helper function `postprocess_with_tf2` refines the raw YOLOv8 detections using TensorFlow utilities for bounding box handling.
# It allows consistent filtering, class selection, and non-maximum suppression (NMS) in a **TensorFlow-friendly pipeline**.
#
# Steps inside the function:
# 1. **Run YOLOv8**: Calls `run_yolov8` to get raw detections (boxes, confidence, class IDs).
# 2. **Tensor Conversion**: Converts confidence scores and bounding boxes to TensorFlow tensors.
# 3. **One-Hot Encoding of Classes**: Builds a one-hot representation of predicted classes for TensorFlow operations.
# 4. **Bounding Box Post-Processing**: Uses `yolo_eval` to apply:
#    - Confidence threshold filtering.
#    - IoU threshold filtering (Non-Maximum Suppression).
#    - Per-class NMS to handle overlapping boxes of the same object.
# 5. **Class Filtering**: If a `wanted_class` is specified (e.g., `"car"`), detections are restricted to that class only.
# 6. **Returns**:
#    - Final confidence scores.
#    - Refined bounding boxes in `(y1, x1, y2, x2)` format.
#    - Predicted class IDs.
#
# This post-processing step is useful for comparing **YOLO’s built-in handling** with a **TensorFlow-based approach**, and for seamlessly integrating detections into downstream TensorFlow models or pipelines.

# %%
def postprocess_with_tf2(image_path, score_threshold=0.25, iou_threshold=0.5, max_boxes=50, wanted_class="truck"):
    # Get YOLOv8 raw detections
    yx_boxes, conf, cls = run_yolov8(image_path, score_threshold=0.0, iou_threshold=0.7)
    if yx_boxes.shape[0] == 0:
        return np.zeros((0,), np.float32), np.zeros((0,4), np.float32), np.zeros((0,), np.int32)

    N, C = yx_boxes.shape[0], len(class_names)
    box_conf = tf.convert_to_tensor(conf.reshape(1, N, 1), dtype=tf.float32)
    boxes    = tf.convert_to_tensor(yx_boxes.reshape(1, N, 4), dtype=tf.float32)

    # One-hot class probabilities
    probs = np.zeros((1, N, C), dtype=np.float32)
    for i, c in enumerate(cls):
        if 0 <= c < C:
            probs[0, i, c] = 1.0
    box_probs = tf.convert_to_tensor(probs, dtype=tf.float32)

    with Image.open(image_path) as im:
        H, W = im.height, im.width

    scores, fboxes, classes = yolo_eval(
        box_conf, boxes, box_probs,
        image_shape=(H, W),
        max_boxes=max_boxes,
        score_threshold=score_threshold,
        iou_threshold=iou_threshold,
        per_class_nms=True
    )

    # Optionally filter wanted class
    if wanted_class in class_names:
        idx = class_names.index(wanted_class)
        mask = tf.where(classes == idx)[:,0]
        scores = tf.gather(scores, mask)
        fboxes = tf.gather(fboxes, mask)
        classes = tf.gather(classes, mask)

    return scores.numpy(), fboxes.numpy(), classes.numpy()

# %% [markdown]
# ## Test YOLO Pretrained Model on Images
#
#
#
# In this step, we prepare the **label space** and **anchor priors** used by YOLO:
# - **COCO class names** (`coco_classes.txt`): human-readable labels for each predicted class.
# - **YOLO anchors** (`yolo_anchors.txt`): width–height priors (in pixels) that guide the detector when proposing bounding boxes.
#
# The code below:
# 1. Loads class names and anchor boxes from your `model_data/` folder.
# 2. Computes basic stats (number of classes/anchors).
# 3. Prints a quick preview of both to verify the setup.
#
# > If your files are in a different location, update `class_file` and `anchors_path` accordingly.
#
# ### **What Are Anchors in YOLO?**
#
# **Anchors** are predefined bounding box shapes (width × height) that act as *priors* to help YOLO detect objects of different sizes and aspect ratios.
# Instead of predicting bounding boxes from scratch, YOLO learns **offsets** relative to these anchors.
#
# - Each grid cell on the feature map predicts multiple bounding boxes, one per anchor.
# - Anchors are chosen to reflect common object shapes in the training dataset (e.g., tall boxes for people, wide boxes for cars).
# - During training, YOLO matches ground truth boxes to the **closest anchor shape**, making learning more stable.
#
# **Why are anchors useful?**
# - They let the model efficiently handle **multi-scale objects** in the same image.
# - They reduce the search space for bounding box regression, speeding up detection.
# - They improve accuracy by giving the network better "starting guesses" for box shapes.
#
# In practice, YOLO uses 9 anchor boxes (in YOLOv3/v4) or different sets depending on the variant, tuned for the COCO dataset.
# Your `yolo_anchors.txt` file defines these anchor dimensions, which are loaded above and used during inference.

# %%
# Load class names from model_data
class_file = "content/Lab4/model_data/coco_classes.txt"   # adjust path if needed
anchors_path = "content/Lab4/model_data/yolo_anchors.txt"
class_names = yolo_utils.read_classes(class_file)
anchors = yolo_utils.read_anchors(anchors_path)

num_classes = len(class_names)
num_anchors = anchors.shape[0]

print("Loaded", len(class_names), "classes.")
print("Example:", class_names[:10])
print("Loaded", len(anchors), "anchors.")
print("Example:", anchors[:10])
# Out:
# Loaded 80 classes.
# Example: ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light']
# Loaded 5 anchors.
# Example: [[    0.57273     0.67739]
#  [     1.8745      2.0625]
#  [     3.3384      5.4743]
#  [     7.8828      3.5278]
#  [     9.7705      9.1683]]

# %% [markdown]
# ### Testing YOLOv8 on a Sample Road Scene
#
# In this step, we run **YOLOv8** directly on a chosen test image (e.g., a road scene).
#
# Process:
# 1. **Select an image** – here `0114.jpg` is used from the dataset.
# 2. **Run YOLOv8 inference** using `run_yolov8` with a confidence threshold of `0.25` and IoU threshold of `0.45`.
# 3. **Filter detections** so that only the target class (`car`) is drawn.
# 4. **Visualize results** with `draw_boxes`, which overlays bounding boxes and labels onto the image.
# 5. **Output** the number of detected cars and the annotated image.
#
# This confirms the model can correctly identify cars in a realistic driving scenario and gives a first look at the quality of detections.

# %%
image_path = "content/Lab4/images/0110.jpg"   # put your test road scene here

# Direct YOLOv8
boxes, scores, classes = run_yolov8(image_path, score_threshold=0.30, iou_threshold=0.25)
vis, count = draw_boxes(image_path, boxes, scores, classes, class_names=class_names, wanted_idx=class_names.index("car"))
print("Cars detected (direct):", count)
display(vis)

 #score_threshold is the confidence level. more value, more accurate
 #1) when score_threshold = 0.30 iou_threshold0.75  No of detected cars=6
 #when score_threshold = 0.60 iou_threshold0.75  No of detected cars=0
 #when score_threshold = 0.90 iou_threshold0.75  No of detected cars=0

 #iou_threshold means the overlap. when higher more overlap
 #1) when score_threshold = 0.30 iou_threshold0.25  No of detected cars=5
 #when score_threshold = 0.60 iou_threshold0.25  No of detected cars=0
 #when score_threshold = 0.90 iou_threshold0.25  No of detected cars=0

 # in scenario 1)once the iou_threshold increases,
        #more accurate detected with less overlapping bounding boxes is achieved
# Out:
# Cars detected (direct): 4
# <PIL.Image.Image image mode=RGB size=1280x720>

# %% [markdown]
# ### Confidence & IoU Thresholds — What They Mean and What to Try
#
# When you call `run_yolov8(image_path, score_threshold=0.25, iou_threshold=0.45)`, two key thresholds control what boxes you see:
#
# 1) Confidence (score) threshold
# - Meaning: Minimum predicted confidence for a box to be kept (objectness × class score).
# - Lower value (e.g., 0.25): keeps more boxes → more true positives but also more false positives.
# - Higher value (e.g., 0.60 or 0.90): keeps fewer boxes → fewer false positives but risks missing true objects.
#
# 2) IoU threshold (used in Non-Maximum Suppression, NMS)
# - Meaning: Intersection-over-Union overlap at which two boxes are considered “the same” object and the lower-scored one is suppressed.
# - Lower IoU (e.g., 0.45): more aggressive suppression → fewer overlapping boxes, may drop some valid close boxes.
# - Higher IoU (e.g., 0.75): less aggressive suppression → can keep more overlapping boxes, may show duplicates on the same object.
#
# Exercise:
# - Run the cell above code as it is, then change `score_threshold` to 0.30, 0.60, 0.90 and observe: number of cars, missed detections, and spurious boxes.
# - Try `iou_threshold` values 0.45 vs 0.75 and note how overlapping boxes behave.
# - Record your observations (2–3 sentences) about the precision–recall trade-off.

# %% [markdown]
# ### Batch Processing a Folder of Images
#
# So far, we have tested YOLO on a **single image**.
# The helper function `process_folder` extends this by running inference on **all images in a folder** and automatically producing a simple report.
#
# What the function does:
# 1. Loops through each file in the specified `folder` (default = `"images"`).
# 2. Runs `run_yolov8` to detect objects.
# 3. Calls `draw_boxes` to visualize **only cars** (`wanted_idx=car`).
# 4. Saves annotated images into an output folder (`out/`) if `save_out=True`.
# 5. Builds a report listing the image filename and the number of cars detected (or an error message if inference failed).
#
# **Return Value:**
# A Python list of `(filename, car_count)` pairs, e.g.:
# ```python
# [("0114.jpg", 3), ("0115.jpg", 5), ("0116.jpg", 0)]

# %%
def process_folder(folder="images", min_score=0.25, save_out=True):
    out_dir = "out"
    os.makedirs(out_dir, exist_ok=True)
    report = []
    for img_file in glob.glob(os.path.join(folder, "*.*")):
        try:
            boxes, scores, classes = run_yolov8(img_file, score_threshold=min_score, iou_threshold=0.45)
            vis, car_count = draw_boxes(img_file, boxes, scores, classes, class_names=class_names, wanted_idx=class_names.index("car"))
            if save_out:
                vis.save(os.path.join(out_dir, os.path.basename(img_file)))
            report.append((os.path.basename(img_file), car_count))
        except Exception as e:
            report.append((os.path.basename(img_file), f"error: {e}"))
    return report

# Example:
# counts = process_folder("images")
# counts

# %%
#Example:
counts = process_folder("content/Lab4/images")
counts
# Out:
# [('0109.jpg', 6),
#  ('test.jpg', 13),
#  ('0105.jpg', 3),
#  ('0112.jpg', 2),
#  ('0101.jpg', 1),
#  ('0107.jpg', 2),
#  ('0110.jpg', 5),
#  ('0113.jpg', 2),
#  ('0120.jpg', 5),
#  ('0102.jpg', 2),
#  ('0104.jpg', 1),
#  ('0106.jpg', 4),
#  ('0100.jpg', 1),
#  ('0108.jpg', 3),
#  ('0116.jpg', 1),
#  ('giraffe_resized.jpg', 0),
#  ('0103.jpg', 2),
#  ('0119.jpg', 5),
#  ('0115.jpg', 1),
#  ('0111.jpg', 2),
#  ('0117.jpg', 3),
#  ('0118.jpg', 2),
#  ('DSC_1643_resized.jpg', 6),
#  ('0114.jpg', 1)]

# %% [markdown]
# ### Advanced Task 1: Class-wise Filtering and Comparison
#
# So far you filtered only one class (e.g., `car`).
# **Now extend this idea** to detect and compare **two classes** (e.g., `car` vs `person`).
#
# - Run detection for both classes separately.
# - Count how many detections appear for each class across your dataset.
# - Plot a **bar chart** comparing the counts.
#
# **Deliverable:** A bar chart with class counts and a short note (2–3 sentences) on which class the model detects more reliably in your dataset.

# %%
from collections import Counter

# Multi-class comparison
target_classes = ["car", "person", "bus", "truck", "motorcycle"]
name_to_id = {v:k for k,v in model.names.items()}

counts = Counter()

for img_file in glob.glob("content/Lab4/images/*.*"):
    results = model.predict(img_file, conf=0.25, iou=0.45, verbose=False)
    r = results[0]
    if r.boxes is None:
        continue
    cls_ids = r.boxes.cls.cpu().numpy().astype(int)
    for t in target_classes:
        if name_to_id[t] in cls_ids:
            counts[t] += (cls_ids == name_to_id[t]).sum()

# Bar chart
plt.bar(counts.keys(), counts.values())
plt.ylabel("Detections")
plt.title("Class-wise detection counts")
plt.show()

# Pie chart version
plt.pie(counts.values(), labels=counts.keys(), autopct="%1.1f%%")
plt.title("Class-wise detection distribution")
plt.show()

# %% [markdown]
# ### Advanced Task 2: Threshold Sweep with Detection Counts
#
# You already tried changing confidence manually.
# Now automate it:
# - Sweep across confidence thresholds (0.1 → 0.9).
# - Count how many cars are detected at each threshold.
# - Plot detections vs threshold as a line chart.
#
# **Deliverable:** A plot showing the trade-off, and a sentence describing the “sweet spot” threshold for your dataset.

# %%
conf_list = [0.1,0.2,0.3,0.5,0.7,0.9]
counts = []

for conf in conf_list:
    total = 0
    for img_file in glob.glob("content/Lab4/images/*.*"):
        boxes, scores, classes = run_yolov8(img_file, score_threshold=conf, iou_threshold=0.45)
        total += (classes == class_names.index("car")).sum()
    counts.append(total)

plt.plot(conf_list, counts, marker="o")
plt.xlabel("Confidence Threshold")
plt.ylabel("Number of Cars Detected")
plt.title("Car detections vs Confidence Threshold")
plt.grid(True)
plt.show()

# %% [markdown]
# # Lab 4 Wrap-Up – Autonomous Driving: Car Detection
#
# In this lab, you:
#
# - Reviewed **CNN basics** and their role in object detection.
# - Applied a **pretrained YOLOv8 model** to detect cars (and other objects) in road scenes.
# - Learned to **draw bounding boxes** and filter by class.
# - Experimented with **confidence and IoU thresholds**, seeing their effect on detections.
# - Completed **Advanced Tasks**:
#   1. Multi-class detection comparison (bar/pie charts).
#   2. Confidence threshold sweeps and their effect on car counts.
#
# ---
#
# ### 📌 Final Deliverable
# 1. Make sure your notebook is clean, well-commented, and runs end-to-end.
# 2. Upload your updated notebook (`autonomous_driving_application_car_detection.ipynb`) to your **GitHub repository**.
# 3. Submit the **GitHub link** on **CourseWeb** as your final submission for Lab 4.
#
# ---
